# %%
import sdp_cnvrt
import scs
data,cone=sdp_cnvrt.scs_form("theta1.dat-s")
sol = scs.solve(data,
                cone,
                use_indirect=False,
                gpu=False,
                verbose=True,
                normalize=True,
                max_iters=2000,
                scale=1,
                eps=1e-3,
                cg_rate=2,
                alpha=1.5,
                rho_x=1e-3,
                acceleration_lookback=10,
                write_data_filename=None)
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 153
# eps = 1.00e-03, alpha = 1.50, max_iters = 2000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 104, constraints m = 1275
# Cones:	sd vars: 1275, sd blks: 1
# Setup time: 2.59e-02s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 5.55e+19  2.34e+21  9.97e-01  2.32e+20  1.56e+23  4.28e+20  1.08e-02
#    100| 3.28e-03  4.15e-02  3.04e-03  2.31e+01  2.29e+01  8.75e-15  1.52e-01
#    200| 1.19e-04  3.39e-04  3.42e-04  2.30e+01  2.30e+01  3.89e-14  3.19e-01
# ...

# %%
import sdp_cnvrt
import scs
data,cone=sdp_cnvrt.scs_form("theta2.dat-s")
sol = scs.solve(data,
                cone,
                use_indirect=False,
                gpu=False,
                verbose=True,
                normalize=True,
                max_iters=2000,
                scale=1,
                eps=1e-3,
                cg_rate=2,
                alpha=1.5,
                rho_x=1e-3,
                acceleration_lookback=10,
                write_data_filename=None)
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 597
# eps = 1.00e-03, alpha = 1.50, max_iters = 2000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 498, constraints m = 5050
# Cones:	sd vars: 5050, sd blks: 1
# Setup time: 4.09e-02s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 3.78e+00  1.99e+02  9.98e-01  1.53e+01  2.00e+04  0.00e+00  2.37e-02
#    100| 6.34e-03  7.88e-02  5.23e-03  3.33e+01  3.29e+01  1.00e-14  1.15e+00
#    200| 2.38e-03  4.29e-02  1.08e-02  3.30e+01  3.23e+01  5.49e-14  2.18e+00
# ...

# %%
import sdp_cnvrt
import scs
data,cone=sdp_cnvrt.scs_form("infd1.dat-s")
sol = scs.solve(data,
                cone,
                use_indirect=False,
                gpu=False,
                verbose=True,
                normalize=True,
                max_iters=2000,
                scale=1,
                eps=1e-3,
                cg_rate=2,
                alpha=1.5,
                rho_x=1e-3,
                acceleration_lookback=10,
                write_data_filename=None)
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 4650
# eps = 1.00e-03, alpha = 1.50, max_iters = 2000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 10, constraints m = 465
# Cones:	sd vars: 465, sd blks: 1
# Setup time: 2.08e-02s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 3.86e-01  3.30e+00  9.30e-01 -8.11e+00  5.24e+00  1.84e-14  1.41e-02
#     28| 5.23e+08  0.00e+00  1.00e+00 -1.49e+21 -0.00e+00  1.49e+21  2.96e-02
# ----------------------------------------------------------------------------
# ...

# %%
import sdp_cnvrt
import scs
data,cone=sdp_cnvrt.scs_form("infd2.dat-s")
sol = scs.solve(data,
                cone,
                use_indirect=False,
                gpu=False,
                verbose=True,
                normalize=True,
                max_iters=2000,
                scale=1,
                eps=1e-3,
                cg_rate=2,
                alpha=1.5,
                rho_x=1e-3,
                acceleration_lookback=10,
                write_data_filename=None)
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 4650
# eps = 1.00e-03, alpha = 1.50, max_iters = 2000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 10, constraints m = 465
# Cones:	sd vars: 465, sd blks: 1
# Setup time: 2.17e-02s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.37e+00  1.45e+01  9.85e-01 -8.73e+00  5.69e+01  1.58e-14  9.97e-03
#     35| 9.42e+08  0.00e+00  1.00e+00 -5.95e+20 -0.00e+00  5.95e+20  2.54e-02
# ----------------------------------------------------------------------------
# ...

# %%
import sdp_cnvrt
import scs
import importlib
importlib.reload(sdp_cnvrt)
data,cone=sdp_cnvrt.scs_form("maxG11.dat-s")
sol = scs.solve(data,
                cone,
                use_indirect=False,
                gpu=False,
                verbose=True,
                normalize=True,
                max_iters=2000,
                scale=1,
                eps=1e-3,
                cg_rate=2,
                alpha=1.5,
                rho_x=1e-3,
                acceleration_lookback=10,
                write_data_filename=None)
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 800
# eps = 1.00e-03, alpha = 1.50, max_iters = 2000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 800, constraints m = 320400
# Cones:	sd vars: 320400, sd blks: 1
# Setup time: 3.13e-01s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.82e+00  4.74e+02  1.00e+00  4.11e+01  2.33e+05  5.11e-11  2.04e+00
#    100| 4.52e-01  1.78e+02  1.00e+00  1.84e+04 -2.11e+03  1.47e-11  1.39e+02
#    200| 2.20e-02  9.66e-01  1.00e+00  5.55e+03 -0.00e+00  2.07e-12  2.49e+02
# ...
